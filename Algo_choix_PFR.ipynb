# %% [markdown]
# ## Prototype, choix des projets
#
# Principe:
# On lit dans le fichier Excel les préférences de chacun.
# Un nombre d'utilisateurs "bidons" sont rajoutés pour arriver à 64 personnes
# On construit une matrice de coût pour chaque personne et chaque place dans un projet.
#
# Choix de coût arbitraire ici:
# - 0 pour choix 1
# - 10 pour choix 2
# - 20 pour choix 3
# - 40 pour choix 4
# - 60 pour choix 5
# - 200 si hors classement
#
# **On pourrait à la place demander de noter chaque projets ("très intéressé", "intéressé", "peu intéressé", "je ne veux pas le faire", "je n'ai pas le droit") avec un coût associé.** Cela reflètera sans doute mieux les préférences de chacun pour la répartition initiale.
#
# On distingue les places de chaque projet:
# - place n°1 : favorise les math
# - place n°2 : favorise l'info
# - place n°3 : favorise la gestion de projets
# - place n°4 : sans préférence
#
# La place n°4 est aussi la seule qui accepte un utilisateur bidon (pour éviter d'avoir des projets à moins de 3 personnes)
#
# Ici, une faible pondération a été utilisée qui ne prend pas le pas sur les préférences. Il suffit de la mettre à zéro pour ne pas tenir compte du tout de ce critère. Dans le cas du prototype, j'ai l'impression que ça influe quand même beaucoup (ça enlève une part de hasard pour savoir qui va sur les projets qui intéressent beaucoup ou au contraire n'intéressent personne).
#
# Un peu de bruit aléatoire est finalement ajouté à la matrice de coût pour briser les symétries (si deux personnes font exactement le même choix et qu'il y n'y a qu'une place, c'est de là que viendra la décision en dernier ressort)
#
# La matrice est passé dans une fonction d'optimisation qui affecte à chaque personne un projet de sorte à minimiser le coût total (cf: problème d'assignation, algorithme hongrois).
#
# Il y a encore beaucoup d'aléa, en refaisant plusieurs foid le tirage j'ai terminé presque à chaque fois dans un groupe différent.

# %%
import numpy as np
import pandas as pd
# La fonction qui permet de résoudre le problème
from scipy.optimize import linear_sum_assignment

# %% [markdown]
# ### Import des données

# %%
df_choix= pd.read_excel('~/MS-IA/FilRouge/Fil Rouge (réponses).xlsx')

# %%
#Delete duplicate submissions, keep only last
df_choix = df_choix.drop_duplicates(subset='Email',keep='last')
print(f"{len(df_choix)} participants pour le moment")
# Out:
# 53 participants pour le moment

# %%
df_choix
# Out:
#                 Horodateur                                Email     Choix 1  \
# 0  2019-10-24 20:31:09.635     antonin.durieux@telecom-paris.fr       ENGIE
# 1  2019-10-24 21:18:22.769                 zhiya.duan@gmail.com      SAFRAN
# 2  2019-10-24 21:18:48.999             sophieleveugle@gmail.com         IBM
# 3  2019-10-24 21:32:34.375                helene.danlos@free.fr       ENGIE
# 4  2019-10-24 21:33:33.535                  romain_leg@yahoo.fr       ENGIE
# 5  2019-10-24 21:47:11.267                brice_tayart@yahoo.fr      SAFRAN
# 6  2019-10-24 21:51:43.409              wangyangbenny@gmail.com         IBM
# 7  2019-10-24 22:09:12.812                    sjd1882@gmail.com         IBM
# 8  2019-10-24 22:45:41.029         paul.legoux@telecom-paris.fr     UBISOFT
# 9  2019-10-25 00:16:10.961         axel.camara@telecom-paris.fr      VEEPEE
# 10 2019-10-25 00:25:00.433    hicham.elouatiki@telecom-paris.fr         IBM
# 11 2019-10-25 00:30:19.056          hamza.amri@telecom-paris.fr      VEEPEE
# 12 2019-10-25 01:08:42.675    cyrille.nouboue àtelecom-paris.fr         IBM
# 13 2019-10-25 07:55:53.765              riviere.thomas@yahoo.fr         IBM
# 14 2019-10-25 08:35:18.429  guillaume.lehericy@telecom-paris.fr         IBM
# 15 2019-10-25 08:36:24.707         antoine.hue@telecom-paris.fr  Airbus D&S
# 16 2019-10-25 08:41:47.397  nicolas.louis@telecom-paristech.org         IBM
# 17 2019-10-25 09:09:55.796            kevin.lu@telecom-paris.fr         IBM
# 18 2019-10-25 09:10:18.530    vladimir.steiner@telecom-paris.fr         IBM
# 19 2019-10-25 09:13:33.735    thomas.jacquemin@telecom-paris.fr  Airbus D&S
# 20 2019-10-25 09:19:42.862                 sunbenyang@gmail.com       ENGIE
# 21 2019-10-25 09:45:26.946     vincent.richard@telecom-paris.fr      IDEMIA
# 22 2019-10-25 09:53:05.111                 tinarey110@gmail.com  Airbus D&S
# 23 2019-10-25 10:16:12.674             malick.gouba@outlook.com         IBM
# 24 2019-10-25 10:49:02.920          philippe.benezeth@gmail.com       ENGIE
# 25 2019-10-25 10:49:28.245                erwanfloch@hotmail.fr       ENGIE
# 26 2019-10-25 10:49:58.050    xavier.bracquart@telecom-paris.fr       ENGIE
# 27 2019-10-25 10:51:41.841         thomas.koch.ea2011@gmail.com       ENGIE
# 28 2019-10-25 10:52:01.985                 yam.hiroto@gmail.com         IBM
# 29 2019-10-25 10:53:15.185             pfangue@telecom-paris.fr       ENGIE
# 30 2019-10-25 10:53:45.732           francois.culiere@gmail.com      VEEPEE
# 31 2019-10-25 10:54:54.945             chloe.younes.v@gmail.com       ENGIE
# 32 2019-10-25 11:01:28.570             matthieu.desse@gmail.com      VEEPEE
# 33 2019-10-25 11:04:15.728                   lea.diwu@gmail.com      VEEPEE
# 34 2019-10-25 11:42:11.332    vincent.martinez@telecom-paris.fr       ENGIE
# 35 2019-10-25 11:50:21.612             cochenercamille@yahoo.fr      VEEPEE
# 36 2019-10-25 11:53:58.988               savoure.gael@gmail.com  Airbus D&S
# 37 2019-10-25 11:58:18.206            baptiste.geslin@gmail.com     CIL4SYS
# 38 2019-10-25 12:03:58.502    jorge.antequera@telecom-paris.com  Airbus D&S
# 39 2019-10-25 12:11:01.344               ongonoolinga@gmail.com      VEEPEE
# 41 2019-10-25 12:14:29.715         Jeanjules.bigeard@gmail.com   Airbus D&S
# 42 2019-10-25 12:23:04.871      babacar.diouf@telecom-paris..fr         IBM
# 43 2019-10-25 12:39:50.822               xi.li@telecom-paris.fr      SAFRAN
# 44 2019-10-25 12:48:42.882              thomas.mensch@gmail.com      IDEMIA
# 45 2019-10-25 13:05:45.367        rakotoniaina@telecom-paris.fr      IDEMIA
# 46 2019-10-25 13:13:12.762      Imane.aghmari@telecom-paris.com      IDEMIA
# 47 2019-10-25 13:17:59.723                    ckaelig@gmail.com  Airbus D&S
# 48 2019-10-25 13:18:08.766          rodolphe.simoneau@essec.edu         IBM
# 49 2019-10-25 13:20:07.593                xu19@telecom-paris.fr      VEEPEE
# 50 2019-10-25 13:23:07.079              julien.g56520@orange.fr      SAFRAN
# 51 2019-10-25 13:24:27.597    emmanuel.doumard@telecom-paris.fr     UBISOFT
# 52 2019-10-25 13:26:54.957        sonia.bouden@telecom-paris.fr      VEEPEE
# 53 2019-10-25 13:28:53.892             aouani.elhabib@gmail.com      SAFRAN
#
#                  Choix 2               Choix 3               Choix 4  \
# 0                  VALEO                VEEPEE               CIL4SYS
# 1                 VEEPEE                IDEMIA                   IBM
# 2                 VEEPEE                  AXYS                IDEMIA
# 3                 TECNIP            Delta Dore               UBISOFT
# 4                 VEEPEE  Ministère des Armées                TECNIP
# 5   Ministère des Armées                IDEMIA                   IBM
# 6                 IDEMIA                SAFRAN                 ENGIE
# 7                 IDEMIA                SAFRAN            Airbus D&S
# 8                 VEEPEE            Airbus D&S                IDEMIA
# 9                UBISOFT                SAFRAN                   IBM
# 10                SAFRAN                 ENGIE               Karavel
# 11            Airbus D&S                 ENGIE                   IBM
# 12                VEEPEE                IDEMIA               Karavel
# 13                IDEMIA            Airbus D&S                 ENGIE
# 14               UBISOFT                IDEMIA  Ministère des Armées
# 15  Ministère des Armées                IDEMIA                   IBM
# 16            Airbus D&S                 ENGIE                IDEMIA
# 17                IDEMIA               UBISOFT                VEEPEE
# 18               UBISOFT                  AXYS                IDEMIA
# 19                   IBM  Ministère des Armées                SAFRAN
# 20                VEEPEE         BEARING POINT                 VALEO
# 21                SAFRAN                VEEPEE               Karavel
# 22                IDEMIA                   IBM                 VALEO
# 23                VEEPEE                SAFRAN                 ENGIE
# 24                TECNIP            Airbus D&S                 VALEO
# 25                TECNIP            Airbus D&S                 VALEO
# 26                TECNIP            Airbus D&S                 VALEO
# 27                TECNIP            Airbus D&S                 VALEO
# 28            Airbus D&S                VEEPEE                IDEMIA
# 29                VEEPEE                 VALEO                   IBM
# 30                 ENGIE  Ministère des Armées                   IBM
# 31                VEEPEE                TECNIP            Airbus D&S
# 32                IDEMIA  Ministère des Armées            Airbus D&S
# 33                IDEMIA               UBISOFT                 ENGIE
# 34            Airbus D&S                   IBM                IDEMIA
# 35                   IBM                 VALEO                IDEMIA
# 36               UBISOFT                   IBM                 ENGIE
# 37            Delta Dore         BEARING POINT                 ENGIE
# 38                IDEMIA                VEEPEE                   IBM
# 39               Karavel                   IBM                  AXYS
# 41                SAFRAN                IDEMIA  Ministère des Armées
# 42                  AXYS                 VALEO         BEARING POINT
# 43                 ENGIE               UBISOFT                IDEMIA
# 44                 ENGIE            Airbus D&S                 VALEO
# 45                 ENGIE                   IBM                  AXYS
# 46                VEEPEE            Airbus D&S                   IBM
# 47                IDEMIA                 VALEO               UBISOFT
# 48                VEEPEE                  AXYS               Karavel
# 49                IDEMIA                   IBM            Airbus D&S
# 50  Ministère des Armées            Airbus D&S                   IBM
# 51                IDEMIA                VEEPEE                 VALEO
# 52                 ENGIE                 VALEO                SAFRAN
# 53                VEEPEE                TECNIP            Airbus D&S
#
#                  Choix 5  Maths  Informatique  Gestion de projet       .1  \
# 0             Delta Dore      3             4                  3 NaN  NaN
# 1                  ENGIE      4             3                  3 NaN  NaN
# 2                Karavel      4             2                  4 NaN  NaN
# 3                  VALEO      2             4                  4 NaN  NaN
# 4                 IDEMIA      5             2                  2 NaN  NaN
# 5                 VEEPEE      5             2                  3 NaN  NaN
# 6             Airbus D&S      4             4                  5 NaN  NaN
# 7                  ENGIE      5             4                  3 NaN  NaN
# 8                    IBM      4             4                  3 NaN  NaN
# 9                  ENGIE      2             4                  3 NaN  NaN
# 10             GROUPE HN      3             3                  4 NaN  NaN
# 11                 VALEO      5             4                  1 NaN  NaN
# 12               CIL4SYS      3             4                  2 NaN  NaN
# 13                VEEPEE      2             4                  3 NaN  NaN
# 14                 VALEO      3             4                  3 NaN  NaN
# 15                SAFRAN      4             5                  4 NaN  NaN
# 16         BEARING POINT      3             2                  5 NaN  NaN
# 17                  AXYS      3             4                  3 NaN  NaN
# 18                VEEPEE      3             4                  2 NaN  NaN
# 19                IDEMIA      3             5                  3 NaN  NaN
# 20                   IBM      3             4                  3 NaN  NaN
# 21  Ministère des Armées      2             5                  3 NaN  NaN
# 22               UBISOFT      3             4                  4 NaN  NaN
# 23                IDEMIA      4             3                  3 NaN  NaN
# 24                   IBM      4             1                  5 NaN  NaN
# 25                   IBM      2             1                  4 NaN  NaN
# 26                   IBM      2             5                  2 NaN  NaN
# 27                   IBM      3             2                  4 NaN  NaN
# 28               Karavel      3             2                  5 NaN  NaN
# 29         BEARING POINT      4             3                  2 NaN  NaN
# 30               Karavel      4             3                  2 NaN  NaN
# 31                IDEMIA      4             3                  2 NaN  NaN
# 32               UBISOFT      4             2                  5 NaN  NaN
# 33            Airbus D&S      3             3                  5 NaN  NaN
# 34                 VALEO      3             5                  5 NaN  NaN
# 35  Ministère des Armées      4             3                  5 NaN  NaN
# 36                TECNIP      2             4                  3 NaN  NaN
# 37                 VALEO      3             3                  3 NaN  NaN
# 38               UBISOFT      4             4                  2 NaN  NaN
# 39            Delta Dore      3             2                  4 NaN  NaN
# 41               CIL4SYS      4             4                  4 NaN  NaN
# 42            Airbus D&S      3             2                  3 NaN  NaN
# 43                VEEPEE      5             3                  3 NaN  NaN
# 44                SAFRAN      3             4                  4 NaN  NaN
# 45         BEARING POINT      3             2                  2 NaN  NaN
# 46                 ENGIE      4             3                  4 NaN  NaN
# 47                 ENGIE      3             3                  4 NaN  NaN
# 48                IDEMIA      2             3                  5 NaN  NaN
# 49                 VALEO      3             5                  3 NaN  NaN
# 50               CIL4SYS      4             3                  2 NaN  NaN
# 51                   IBM      2             4                  2 NaN  NaN
# 52                   IBM      3             1                  5 NaN  NaN
# 53                 ENGIE      3             3                  4 NaN  NaN
#
#      .2   .3   .4   .5
# 0   NaN  NaN  NaN  NaN
# 1   NaN  NaN  NaN  NaN
# 2   NaN  NaN  NaN  NaN
# 3   NaN  NaN  NaN  NaN
# 4   NaN  NaN  NaN  NaN
# 5   NaN  NaN  NaN  NaN
# 6   NaN  NaN  NaN  NaN
# 7   NaN  NaN  NaN  NaN
# 8   NaN  NaN  NaN  NaN
# 9   NaN  NaN  NaN  NaN
# 10  NaN  NaN  NaN  NaN
# 11  NaN  NaN  NaN  NaN
# 12  NaN  NaN  NaN  NaN
# 13  NaN  NaN  NaN  NaN
# 14  NaN  NaN  NaN  NaN
# 15  NaN  NaN  NaN  NaN
# 16  NaN  NaN  NaN  NaN
# 17  NaN  NaN  NaN  NaN
# 18  NaN  NaN  NaN  NaN
# 19  NaN  NaN  NaN  NaN
# 20  NaN  NaN  NaN  NaN
# 21  NaN  NaN  NaN  NaN
# 22  NaN  NaN  NaN  NaN
# 23  NaN  NaN  NaN  NaN
# 24  NaN  NaN  NaN  NaN
# 25  NaN  NaN  NaN  NaN
# 26  NaN  NaN  NaN  NaN
# 27  NaN  NaN  NaN  NaN
# 28  NaN  NaN  NaN  NaN
# 29  NaN  NaN  NaN  NaN
# 30  NaN  NaN  NaN  NaN
# 31  NaN  NaN  NaN  NaN
# 32  NaN  NaN  NaN  NaN
# 33  NaN  NaN  NaN  NaN
# 34  NaN  NaN  NaN  NaN
# 35  NaN  NaN  NaN  NaN
# 36  NaN  NaN  NaN  NaN
# 37  NaN  NaN  NaN  NaN
# 38  NaN  NaN  NaN  NaN
# 39  NaN  NaN  NaN  NaN
# 41  NaN  NaN  NaN  NaN
# 42  NaN  NaN  NaN  NaN
# 43  NaN  NaN  NaN  NaN
# 44  NaN  NaN  NaN  NaN
# 45  NaN  NaN  NaN  NaN
# 46  NaN  NaN  NaN  NaN
# 47  NaN  NaN  NaN  NaN
# 48  NaN  NaN  NaN  NaN
# 49  NaN  NaN  NaN  NaN
# 50  NaN  NaN  NaN  NaN
# 51  NaN  NaN  NaN  NaN
# 52  NaN  NaN  NaN  NaN
# 53  NaN  NaN  NaN  NaN

# %%
# List projets
projects = sorted(list(set(prj for c in range(1,6) for prj in df_choix['Choix %d'%c])))
n_projects = len(projects)
projects
# Out:
# ['AXYS',
#  'Airbus D&S',
#  'BEARING POINT',
#  'CIL4SYS',
#  'Delta Dore',
#  'ENGIE',
#  'GROUPE HN',
#  'IBM',
#  'IDEMIA',
#  'Karavel',
#  'Ministère des Armées',
#  'SAFRAN',
#  'TECNIP',
#  'UBISOFT',
#  'VALEO',
#  'VEEPEE']

# %%
# List users
users = list(df_choix.Email)
n_users_true = len(users)
n_users = 4*n_projects

# On complete par une liste de faux utilisateurs pour arriver à 4 par projet
users.extend(['dummy_%d'%ii for ii in range(n_users_true,n_users)])

# %% [markdown]
# On peut se retrouver avec personne sur un projet (i.e. 4 dummies sur un projet peu demandé)
# Dans un deuxième temps, vu les choix proposés, il faudra ne mettre que 3 places sur les quelques projets les plus problématiques.

# %% [markdown]
# #### Calcul des coûts

# %%
# coûts arbitraires (à régler)
couts = {'Choix 1':0,
         'Choix 2':10,
         'Choix 3':20,
         'Choix 4':40,
         'Choix 5':60,
         'Sans':200}

# %%
# Remplissage d'une matrice de couts
weight_matrix = np.zeros((n_users,n_users))
weight_matrix[:,:n_users_true] = couts['Sans']
for ii_user in range(n_users_true):
    for choix in range(1,6):
        s = 'Choix %d'%choix
        # index du projet choisi
        idx = projects.index(df_choix[s].iloc[ii_user])
        weight_matrix[4*idx:4*idx+4,ii_user] = couts[s]

# %%
# coûts liés aux compétences
# il suffit de mettre 0 pour ne pas les prendre en compte
# La pondération donne la coût maximum pour celui qui a déclaré une note 1/5
ponderation_competences = 5
note_max = 5

# %%
# coûts liés aux compétences
competence_matrix = np.zeros((n_users,n_users_true))

for ii,comp in enumerate(['Maths', 'Informatique', 'Gestion de projet']):
    competence_matrix[ii::4,:] += (ponderation_competences) / note_max \
                                * (note_max - df_choix[comp].values.reshape(1,-1))

dummy_matrix = 1000 * np.ones((n_users,n_users-n_users_true))
dummy_matrix[3::4,:] = 0

# %%
weight_matrix += np.hstack((competence_matrix,dummy_matrix))

# %% [markdown]
# On ajoute une petite quantité aléatoire à chaque coût, assez petite pour ne pas perturber une bonne solution, mais qui permettra de briser des égalités.

# %%
#Randomisation : ajout d'un poids aléatoire pour briser les égalités
weight_matrix += np.random.rand(*weight_matrix.shape)

# %% [markdown]
# #### Résolution
# C'est le coût total qui est optimisé (on peut trouver des personnes très contentes et d'autres très mécontentes)

# %%
optimal_output = linear_sum_assignment(weight_matrix)

# %% [markdown]
# #### Affichage

# %%
for prj,usr in zip(*optimal_output):
    prj_idx = prj//4
    print(projects[prj_idx] + " --> " + users[usr])
# Out:
# AXYS --> sophieleveugle@gmail.com
# AXYS --> vladimir.steiner@telecom-paris.fr
# AXYS --> babacar.diouf@telecom-paris..fr
# AXYS --> dummy_58
# Airbus D&S --> jorge.antequera@telecom-paris.com
# Airbus D&S --> thomas.jacquemin@telecom-paris.fr
# Airbus D&S --> tinarey110@gmail.com
# Airbus D&S --> savoure.gael@gmail.com
# BEARING POINT --> pfangue@telecom-paris.fr
# BEARING POINT --> sunbenyang@gmail.com
# BEARING POINT --> nicolas.louis@telecom-paristech.org
# BEARING POINT --> dummy_59
# CIL4SYS --> julien.g56520@orange.fr
# CIL4SYS --> cyrille.nouboue àtelecom-paris.fr
# CIL4SYS --> Jeanjules.bigeard@gmail.com
# CIL4SYS --> dummy_55
# Delta Dore --> baptiste.geslin@gmail.com
# Delta Dore --> antonin.durieux@telecom-paris.fr
# Delta Dore --> helene.danlos@free.fr
# Delta Dore --> dummy_62
# ENGIE --> romain_leg@yahoo.fr
# ENGIE --> chloe.younes.v@gmail.com
# ENGIE --> vincent.martinez@telecom-paris.fr
# ENGIE --> erwanfloch@hotmail.fr
# GROUPE HN --> hamza.amri@telecom-paris.fr
# GROUPE HN --> kevin.lu@telecom-paris.fr
# GROUPE HN --> hicham.elouatiki@telecom-paris.fr
# GROUPE HN --> dummy_54
# IBM --> sjd1882@gmail.com
# IBM --> riviere.thomas@yahoo.fr
# IBM --> yam.hiroto@gmail.com
# IBM --> malick.gouba@outlook.com
# IDEMIA --> Imane.aghmari@telecom-paris.com
# IDEMIA --> thomas.mensch@gmail.com
# IDEMIA --> wangyangbenny@gmail.com
# IDEMIA --> rakotoniaina@telecom-paris.fr
# Karavel --> ongonoolinga@gmail.com
# Karavel --> vincent.richard@telecom-paris.fr
# Karavel --> rodolphe.simoneau@essec.edu
# Karavel --> dummy_61
# Ministère des Armées --> brice_tayart@yahoo.fr
# Ministère des Armées --> antoine.hue@telecom-paris.fr
# Ministère des Armées --> matthieu.desse@gmail.com
# Ministère des Armées --> dummy_57
# SAFRAN --> xi.li@telecom-paris.fr
# SAFRAN --> zhiya.duan@gmail.com
# SAFRAN --> aouani.elhabib@gmail.com
# SAFRAN --> dummy_53
# TECNIP --> thomas.koch.ea2011@gmail.com
# TECNIP --> xavier.bracquart@telecom-paris.fr
# TECNIP --> philippe.benezeth@gmail.com
# TECNIP --> dummy_56
# UBISOFT --> paul.legoux@telecom-paris.fr
# UBISOFT --> emmanuel.doumard@telecom-paris.fr
# UBISOFT --> guillaume.lehericy@telecom-paris.fr
# UBISOFT --> dummy_63
# VALEO --> cochenercamille@yahoo.fr
# VALEO --> ckaelig@gmail.com
# VALEO --> sonia.bouden@telecom-paris.fr
# VALEO --> dummy_60
# VEEPEE --> francois.culiere@gmail.com
# VEEPEE --> xu19@telecom-paris.fr
# VEEPEE --> lea.diwu@gmail.com
# VEEPEE --> axel.camara@telecom-paris.fr

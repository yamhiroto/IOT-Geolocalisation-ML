# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1)

# %%
data = pd.read_csv("https://bitbucket.org/portierf/shared_files/downloads/data_dm3.csv", sep=',', header=None)

# %%
data
# Out:
#           0         1         2         3         4         5         6    \
# 0   -1.298173 -0.162249  1.223379  1.355554  1.080171  0.634979  0.298741
# 1    0.166951 -0.338060 -0.618867  0.759366  1.134281 -0.536844 -0.075120
# 2   -0.416177 -0.205659 -1.282226  1.675500  1.523746  0.192029 -0.235840
# 3    0.867184 -0.398667  0.093501  0.025971  1.852099  0.789774  0.801775
# 4    1.193282 -0.936980 -0.725039  0.766078  0.223489 -1.584622  1.146866
# 5    1.513286  0.072830  1.243039 -0.368609 -0.564998 -1.736720 -0.441544
# 6   -0.501760  0.191544 -0.225878 -0.240506  1.350852 -1.253936  1.319458
# 7   -1.012528 -1.383290  0.686803  2.146420  1.255864  0.806962  0.137307
# 8    0.532639  1.691226 -0.008375 -1.478906  1.278352 -0.176214 -0.806066
# 9   -0.537216 -0.128677 -0.815059 -1.273897 -0.985841  1.021629 -0.956690
# 10   0.281095  0.892597 -0.604375  1.740050 -1.973232  0.613186  1.138497
# 11   0.207881 -0.133698 -0.781764  0.275791 -0.576272  0.791383  0.435898
# ...

# %%
data.shape
# Out:
# (442, 211)

# %%
X = data.iloc[:, :-1]

# %%
X.shape
# Out:
# (442, 210)

# %%
Y = data.columns[len(data.columns)-1]

# %%
Y = data[data.columns[-1:]]

# %%
Y.shape
# Out:
# (442, 1)

# %%
Y
# Out:
#        210
# 0    151.0
# 1     75.0
# 2    141.0
# 3    206.0
# 4    135.0
# 5     97.0
# 6    138.0
# 7     63.0
# 8    110.0
# 9    310.0
# 10   101.0
# 11    69.0
# 12   179.0
# 13   185.0
# 14   118.0
# 15   171.0
# 16   166.0
# 17   144.0
# 18    97.0
# 19   168.0
# 20    68.0
# 21    49.0
# 22    68.0
# 23   245.0
# 24   184.0
# 25   202.0
# 26   137.0
# 27    85.0
# 28   131.0
# 29   283.0
# ..     ...
# 412  261.0
# 413  113.0
# 414  131.0
# 415  174.0
# 416  257.0
# 417   55.0
# 418   84.0
# 419   42.0
# 420  146.0
# 421  212.0
# 422  233.0
# 423   91.0
# 424  111.0
# 425  152.0
# 426  120.0
# 427   67.0
# 428  310.0
# 429   94.0
# 430  183.0
# 431   66.0
# 432  173.0
# 433   72.0
# 434   49.0
# 435   64.0
# 436   48.0
# 437  178.0
# 438  104.0
# 439  132.0
# 440  220.0
# 441   57.0
#
# [442 rows x 1 columns]

# %%
n, p = X.shape
print("nbr de variables explicatives: {}".format(p))
print("nbr d'observations: {}".format(n))
# Out:
# nbr de variables explicatives: 210
# nbr d'observations: 442

# %% [markdown]
# # 2)

# %%
X_mean = X.mean()

# %%
X_mean
# Les moyennes étant très petites, on peut considérer qu'elles sont centrées (?)
# Out:
# 0      7.535450e-19
# 1     -1.507090e-17
# 2      5.494599e-20
# 3     -7.284269e-18
# 4      8.288995e-18
# 5     -2.712762e-17
# 6      1.971776e-17
# 7      8.540177e-18
# 8      1.029845e-17
# 9      4.018907e-18
# 10    -1.444295e-17
# 11     3.717489e-17
# 12    -3.642134e-17
# 13    -1.124038e-17
# 14    -3.750456e-17
# 15    -4.511851e-17
# 16     2.461580e-17
# 17     9.293722e-18
# 18     2.662526e-17
# 19    -5.601351e-17
# 20    -3.067556e-17
# 21    -4.521270e-18
# 22     6.781905e-18
# 23    -4.056584e-17
# 24     1.004727e-18
# 25    -2.813235e-17
# 26    -3.540092e-17
# 27    -5.953006e-17
# 28    -4.533829e-17
# 29     3.064416e-17
#            ...
# 180   -3.767725e-18
# 181    3.843080e-17
# 182    4.018907e-18
# 183    6.380015e-17
# 184    1.795949e-17
# 185   -1.306145e-17
# 186    1.550053e-17
# 187    3.918434e-17
# 188    1.871304e-17
# 189    1.356381e-17
# 190   -2.737880e-17
# 191    2.210399e-17
# 192   -3.843080e-17
# 193    4.511851e-17
# ...

# %%
plt.scatter(X[0],Y)

# %%
X_sample = data.sample(n=4, random_state=1, axis=1)
XY= pd.concat([X_sample, Y], axis=1)

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
g = sns.pairplot(XY)

# %% [markdown]
# Conclusion: modèle sparse, c'est-à-dire que les variables n'ont pas de corrélation

# %%
np.mean(X) # variables centrées (confirmé par les grapes)
# Out:
# 0      7.535450e-19
# 1     -1.507090e-17
# 2      5.494599e-20
# 3     -7.284269e-18
# 4      8.288995e-18
# 5     -2.712762e-17
# 6      1.971776e-17
# 7      8.540177e-18
# 8      1.029845e-17
# 9      4.018907e-18
# 10    -1.444295e-17
# 11     3.717489e-17
# 12    -3.642134e-17
# 13    -1.124038e-17
# 14    -3.750456e-17
# 15    -4.511851e-17
# 16     2.461580e-17
# 17     9.293722e-18
# 18     2.662526e-17
# 19    -5.601351e-17
# 20    -3.067556e-17
# 21    -4.521270e-18
# 22     6.781905e-18
# 23    -4.056584e-17
# 24     1.004727e-18
# 25    -2.813235e-17
# 26    -3.540092e-17
# 27    -5.953006e-17
# 28    -4.533829e-17
# 29     3.064416e-17
#            ...
# 180   -3.767725e-18
# 181    3.843080e-17
# 182    4.018907e-18
# 183    6.380015e-17
# 184    1.795949e-17
# 185   -1.306145e-17
# 186    1.550053e-17
# 187    3.918434e-17
# 188    1.871304e-17
# 189    1.356381e-17
# 190   -2.737880e-17
# 191    2.210399e-17
# 192   -3.843080e-17
# 193    4.511851e-17
# ...

# %%
np.std(X) # variables normalisées
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      1.0
# 8      1.0
# 9      1.0
# 10     1.0
# 11     1.0
# 12     1.0
# 13     1.0
# 14     1.0
# 15     1.0
# 16     1.0
# 17     1.0
# 18     1.0
# 19     1.0
# 20     1.0
# 21     1.0
# 22     1.0
# 23     1.0
# 24     1.0
# 25     1.0
# 26     1.0
# 27     1.0
# 28     1.0
# 29     1.0
#       ...
# 180    1.0
# 181    1.0
# 182    1.0
# 183    1.0
# 184    1.0
# 185    1.0
# 186    1.0
# 187    1.0
# 188    1.0
# 189    1.0
# 190    1.0
# 191    1.0
# 192    1.0
# 193    1.0
# 194    1.0
# 195    1.0
# 196    1.0
# 197    1.0
# 198    1.0
# 199    1.0
# 200    1.0
# 201    1.0
# 202    1.0
# 203    1.0
# 204    1.0
# 205    1.0
# 206    1.0
# 207    1.0
# 208    1.0
# 209    1.0
# Length: 210, dtype: float64

# %%
print(np.mean(Y))
print(np.std(Y))
# Variable Y non centrée réduite
# Out:
# 210    152.133484
# dtype: float64
# 210    77.005746
# dtype: float64

# %% [markdown]
# # 3)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size=0.2)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (353, 210)
# (89, 210)

# %%
np.std(X_train)
# Out:
# 0      0.993746
# 1      1.019376
# 2      0.997914
# 3      0.999765
# 4      0.997563
# 5      0.999622
# 6      0.972252
# 7      0.998924
# 8      0.983413
# 9      1.012411
# 10     0.997811
# 11     1.010704
# 12     1.014359
# 13     0.994620
# 14     0.994327
# 15     0.963266
# 16     1.016952
# 17     1.009935
# 18     1.003142
# 19     0.997061
# 20     0.995094
# 21     0.943903
# 22     0.984539
# 23     0.965693
# 24     0.974969
# 25     1.017609
# 26     1.019522
# 27     1.023273
# 28     1.004776
# 29     0.983318
#          ...
# 180    1.022346
# 181    0.987113
# 182    1.008260
# 183    1.007674
# 184    0.998905
# 185    0.973743
# 186    0.982812
# 187    1.008260
# 188    0.982450
# 189    0.974134
# 190    1.020036
# 191    0.993540
# 192    1.012726
# 193    1.008928
# 194    1.014694
# 195    1.013938
# 196    0.985131
# 197    1.005745
# 198    0.994547
# 199    1.001431
# 200    0.978550
# 201    1.026191
# 202    0.988221
# 203    0.995205
# ...

# %% [markdown]
# On remarque que X_train n'est plus normalisé (car on ne considère par toutes les mêmes observations)

# %% [markdown]
# => NECESSITE D'UN INTERCEPT

# %% [markdown]
# # 4)

# %%
X_train_cov = np.cov(X_train.T)
X_train_cov.shape
# Out:
# (210, 210)

# %%
from numpy import linalg as LA

# %%
eigen_values = LA.eigh(X_train_cov)
# U, D, Ut = np.linalg.svd(X_train_cov)

# %%
print(eigen_values[1].shape) # Matrice de vecteurs propres
# Out:
# (210, 210)

# %%
print(eigen_values[0].shape) # Matrice des valeurs propres
# Out:
# (210,)

# %%
# eigen_values = np.sort(eigen_values[0]) --> not necessary because the previous method already sorts the values

# %%
xx = np.arange(0, X_train.shape[1])

# %%
#plt.plot(xx, eigen_values[::-1])
plt.plot(xx, eigen_values[0])

# %% [markdown]
# On remarque que les valeurs propres décroissent très vite à partir de la 50ème environ. Il est donc légitime de garder les premières variables, qui ont des valeurs propres qui expliquent bien la variance.

# %% [markdown]
# Le (X.TX)^-1 va être très dur à calculer

# %%
#idx_sort = np.argsort(LA.eigh(X_train_cov)[0], axis=0)

# %%
p2c = p-60

# %%
X2=X.iloc[:, :-p2c]

# %%
X2.shape
# Out:
# (442, 60)

# %% [markdown]
# # 5)

# %% [markdown]
# On recréé une matrice de variables explicatives avec un spectre des plus grandes valeurs propres

# %%
eigen_values[1]
# Out:
# array([[ 0.        ,  0.        ,  0.        , ..., -0.00797695,
#          0.00086187,  0.02807997],
#        [-0.07497796, -0.13087815,  0.05497924, ...,  0.02567172,
#          0.01608349,  0.00315194],
#        [ 0.18460298,  0.20090161, -0.13381446, ...,  0.15871447,
#          0.10107259, -0.17519813],
#        ...,
#        [ 0.02347976,  0.07499803, -0.12142325, ..., -0.09426036,
#         -0.09353884,  0.03607601],
#        [ 0.05950591,  0.05231898, -0.04038747, ...,  0.0319991 ,
#         -0.00933723, -0.00616636],
#        [ 0.01649733,  0.06558524, -0.03322587, ..., -0.11719486,
#         -0.17298067,  0.02934775]])

# %%
#eigen_values[1]
#eigen_vect_60 = eigen_values[1][idx_sort].iloc[:, :-p2c]
eigen_vect_sorted = eigen_values[1][idx_sort]
eigen_vect_60 = eigen_vect_sorted[-60:]

# %%
Y_train, Y_test = train_test_split(Y, test_size=0.2)

# %% [markdown]
#  TODO: recentrer X_train pour coller à ce qui est vu en cour

# %%
np.dot(X_train, eigen_vect_60.T).shape
# Out:
# (353, 60)

# %%
X_tilde = np.dot(X_train, eigen_vect_60.T)

# %%
X_tilde.shape
# Out:
# (353, 60)

# %%
Y_train.shape
# Out:
# (353, 1)

# %%
from sklearn.linear_model import LinearRegression
reg_pca = LinearRegression(fit_intercept=True).fit(X_tilde, Y_train)

# %%
xxx = np.arange(0, len(reg_pca.coef_[0]))

# %%
xxx.shape
# Out:
# (60,)

# %%
reg_pca.coef_.shape
# Out:
# (1, 60)

# %%
plt.plot(xxx, (np.sort(reg_pca.coef_)).T)

# %%
reg = LinearRegression(fit_intercept=True).fit(X_train, Y_train)

# %%
reg.coef_.shape
# Out:
# (1, 210)

# %%
xxxx = np.arange(0, len(reg.coef_[0]))

# %%
plt.plot(xxxx, (np.sort(reg.coef_)).T)

# %% [markdown]
# # 6)

# %%
print(reg_pca.intercept_)
print(reg.intercept_)
# Out:
# [152.18586539]
# [151.93201133]

# %%
print(Y_train.mean())
# Out:
# 210    152.932011
# dtype: float64

# %%
X_tilde_c = [for col in X_tilde] .......
# Out:
# (353, 60)

# %% [markdown]
# # 7)

# %%
X_tilde_test = np.dot(X_test, eigen_vect_60.T)
Y_pred = reg_pca.predict(X_tilde_test)
res_pca = Y_test - Y_pred
fig = plt.figure(figsize=(12,12))
plt.hist(res_pca)
plt.show()

# %%
# Out:
#             210
# 350   82.147121
# 363  -61.704695
# 383  -81.746189
# 199  -40.655111
# 133  -34.828652
# 46     1.692876
# 336  137.853721
# 157  -87.026564
# 304  159.050986
# 440   99.325936
# 346  -23.736700
# 13    64.065857
# 52  -125.196800
# 309    4.838214
# 148  -42.495909
# 119   60.082021
# 83    36.477515
# 124  -51.548126
# 433  -47.417120
# 249   84.563734
# 375   52.476453
# 111 -117.606447
# 213  -56.812164
# 285   70.474160
# 16    43.670709
# 87   -25.521469
# 366   89.285801
# 320  -45.295895
# 432   -9.404490
# 322  110.129471
# ..          ...
# 185  -88.863823
# 142   87.430288
# 176   43.199156
# 202   61.690690
# 281  -55.093579
# 352    1.280907
# 103   44.491467
# 241   41.133096
# 384 -113.081629
# 152  177.879511
# 236  -90.166461
# 171  -78.521263
# 345  -12.650226
# 302   68.294122
# 426  -13.935277
# 98     2.540244
# 247  -36.688783
# 169   36.380865
# 214  -17.810566
# 210  -34.419660
# 393  -51.914250
# 132  -47.990397
# 42  -144.349359
# ...
